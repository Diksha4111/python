# %% [markdown]
# # Welcome to Jupyter!

# %%
#program to print fibonacci series
n=int(input("Enter:"))
a=0
b=1
for i in range(n):
    print(a,end=" ")
    a,b=b,a+b
# Out:
# Enter:5
# 0 1 1 2 3

# %%
print('hello')
# Out:
# hello

# %%
print(2+4)
# Out:
# 6

# %%
print('4'+'8')
# Out:
# 48

# %%
print(5/2)
print(5//2)
print(5**2)
print(5%2)
# Out:
# 2.5
# 2
# 25
# 1

# %%
#by default------print statement prints the output in new line or say next line
#print(<exp>,<exp>,<exp>,........,end="\n")
print(1,2,1+2,2**2,end=" ")
# Out:
# 1 2 3 4

# %%
"it's "+'5:00 pm'
# Out:
# "it's 5:00 pm"

# %%
"hello"+10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-78d895ced238> in <module>
# ----> 1 "hello"+10
#
# TypeError: must be str, not int

# %%
"hello"+"10"
# Out:
# 'hello10'

# %%
x=input("Your name? ")
print(x)
# Out:
# Your name? diksha
# diksha

# %%
a=2
b=10
a or b
# Out:
# 2

# %%
a=2
b=10
a and b
# Out:
# 10

# %%
a=1.1+2.2
b=int(a)
print(b)
b==3
# Out:
# 3
# True

# %%
a=1.1+2.2
print(a)
a==3
# Out:
# 3.3000000000000003
# False
