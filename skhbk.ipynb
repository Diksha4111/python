# %%
#LIST NESTING.
x=[['a','b','c'],[1,['a','b','c'],2]]
for i in x:
    print(i,i[1])
# Out:
# ['a', 'b', 'c'] b
# [1, ['a', 'b', 'c'], 2] ['a', 'b', 'c']

# %%
x=[1,2,3,4]
for i in x:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
x=[1,2,3,5]
print(x.pop(1))
print(x)
print(x.index(3))
# Out:
# 2
# [1, 3, 5]
# 1
